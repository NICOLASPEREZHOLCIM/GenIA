# %% [markdown]
# # Amazon Bedrock boto3 Setup
#
# > *This notebook should work well with the **`Data Science 3.0`** kernel in SageMaker Studio*

# %% [markdown]
# ## Prerequisites
#
# Run the cells in this section to install the packages needed by the notebooks in this workshop. ⚠️ You will see pip dependency errors, you can safely ignore these errors. ⚠️
#
# IGNORE ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.

# %%
# %pip install requests_mock
# Out:
# Collecting requests_mock
#   Downloading requests_mock-1.12.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: requests<3,>=2.22 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from requests_mock) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from requests<3,>=2.22->requests_mock) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from requests<3,>=2.22->requests_mock) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from requests<3,>=2.22->requests_mock) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from requests<3,>=2.22->requests_mock) (2024.6.2)
# Downloading requests_mock-1.12.1-py2.py3-none-any.whl (27 kB)
# Installing collected packages: requests_mock
# Successfully installed requests_mock-1.12.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install --upgrade langchain-core
# Out:
# Requirement already satisfied: langchain-core in c:\users\user\anaconda3\envs\genia\lib\site-packages (0.2.9)
# Collecting langchain-core
#   Downloading langchain_core-0.2.11-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from langchain-core) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from langchain-core) (0.1.81)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from langchain-core) (24.1)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from langchain-core) (2.7.1)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from langchain-core) (8.4.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core) (3.10.5)
# Requirement already satisfied: requests<3,>=2 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core) (2.32.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from pydantic<3,>=1->langchain-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.2 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from pydantic<3,>=1->langchain-core) (2.18.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from pydantic<3,>=1->langchain-core) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain-core) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain-core) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain-core) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.75->langchain-core) (2024.6.2)
# Downloading langchain_core-0.2.11-py3-none-any.whl (337 kB)
#    ---------------------------------------- 0.0/337.4 kB ? eta -:--:--
#    - -------------------------------------- 10.2/337.4 kB ? eta -:--:--
#    --- ----------------------------------- 30.7/337.4 kB 660.6 kB/s eta 0:00:01
#    ------- ------------------------------- 61.4/337.4 kB 544.7 kB/s eta 0:00:01
#    ------------ ------------------------- 112.6/337.4 kB 731.4 kB/s eta 0:00:01
#    ------------------- ------------------ 174.1/337.4 kB 876.1 kB/s eta 0:00:01
#    --------------------------------- ------ 286.7/337.4 kB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 337.4/337.4 kB 1.3 MB/s eta 0:00:00
# Installing collected packages: langchain-core
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.2.9
#     Uninstalling langchain-core-0.2.9:
#       Successfully uninstalled langchain-core-0.2.9
# Successfully installed langchain-core-0.2.11
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install --no-build-isolation --force-reinstall \
    "boto3>=1.28.57" \
    "awscli>=1.29.57" \
    "botocore>=1.31.57"

# %pip install \
    "langchain" \
    "pydantic==1.10.14" \
    "transformers>=4.24,<5" \
    "faiss-cpu>=1.7,<2" \
    "pypdf>=3.8,<4" \
    datasets \
    numexpr 

# %pip install google-search-results
# %pip install SQLAlchemy
# %pip install flask-sqlalchemy --user
# %pip install langchain_community
# %pip install llama-index
# Out:
# Collecting boto3>=1.28.57
#   Downloading boto3-1.34.138-py3-none-any.whl.metadata (6.6 kB)
# Collecting awscli>=1.29.57
#   Downloading awscli-1.33.20-py3-none-any.whl.metadata (11 kB)
# Collecting botocore>=1.31.57
#   Downloading botocore-1.34.138-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3>=1.28.57)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3>=1.28.57)
#   Downloading s3transfer-0.10.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting docutils<0.17,>=0.10 (from awscli>=1.29.57)
#   Downloading docutils-0.16-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting PyYAML<6.1,>=3.10 (from awscli>=1.29.57)
#   Using cached PyYAML-6.0.1-cp311-cp311-win_amd64.whl.metadata (2.1 kB)
# Collecting colorama<0.4.7,>=0.2.5 (from awscli>=1.29.57)
#   Using cached colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting rsa<4.8,>=3.1.2 (from awscli>=1.29.57)
#   Downloading rsa-4.7.2-py3-none-any.whl.metadata (3.6 kB)
# Collecting python-dateutil<3.0.0,>=2.1 (from botocore>=1.31.57)
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3!=2.2.0,<3,>=1.25.4 (from botocore>=1.31.57)
#   Using cached urllib3-2.2.2-py3-none-any.whl.metadata (6.4 kB)
# Collecting six>=1.5 (from python-dateutil<3.0.0,>=2.1->botocore>=1.31.57)
#   Using cached six-1.16.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting pyasn1>=0.1.3 (from rsa<4.8,>=3.1.2->awscli>=1.29.57)
#   Downloading pyasn1-0.6.0-py2.py3-none-any.whl.metadata (8.3 kB)
# Downloading boto3-1.34.138-py3-none-any.whl (139 kB)
#    ---------------------------------------- 0.0/139.2 kB ? eta -:--:--
#    -------- ------------------------------ 30.7/139.2 kB 640.0 kB/s eta 0:00:01
#    -------- ------------------------------ 30.7/139.2 kB 640.0 kB/s eta 0:00:01
#    ------------------------- ------------- 92.2/139.2 kB 655.4 kB/s eta 0:00:01
#    ------------------------------------ - 133.1/139.2 kB 714.4 kB/s eta 0:00:01
#    -------------------------------------- 139.2/139.2 kB 749.6 kB/s eta 0:00:00
# Downloading awscli-1.33.20-py3-none-any.whl (4.5 MB)
#    ---------------------------------------- 0.0/4.5 MB ? eta -:--:--
#    - -------------------------------------- 0.2/4.5 MB 3.5 MB/s eta 0:00:02
#    - -------------------------------------- 0.2/4.5 MB 3.5 MB/s eta 0:00:02
#    --- ------------------------------------ 0.4/4.5 MB 3.0 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.5/4.5 MB 2.5 MB/s eta 0:00:02
#    -------- ------------------------------- 1.0/4.5 MB 4.0 MB/s eta 0:00:01
#    --------- ------------------------------ 1.1/4.5 MB 3.8 MB/s eta 0:00:01
#    ----------------- ---------------------- 2.0/4.5 MB 6.1 MB/s eta 0:00:01
#    -------------------- ------------------- 2.3/4.5 MB 6.1 MB/s eta 0:00:01
#    ------------------------------------ --- 4.1/4.5 MB 9.7 MB/s eta 0:00:01
#    ---------------------------------------  4.5/4.5 MB 9.5 MB/s eta 0:00:01
#    ---------------------------------------- 4.5/4.5 MB 9.5 MB/s eta 0:00:00
# Downloading botocore-1.34.138-py3-none-any.whl (12.4 MB)
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    ---- ----------------------------------- 1.4/12.4 MB ? eta -:--:--
#    ---- ----------------------------------- 1.4/12.4 MB ? eta -:--:--
#    ----------- ---------------------------- 3.4/12.4 MB 31.2 MB/s eta 0:00:01
#    ----------- ---------------------------- 3.4/12.4 MB 31.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.1/12.4 MB 25.0 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.1/12.4 MB 25.0 MB/s eta 0:00:01
#    --------------------- ------------------ 6.5/12.4 MB 22.0 MB/s eta 0:00:01
#    --------------------- ------------------ 6.5/12.4 MB 22.0 MB/s eta 0:00:01
#    -------------------------- ------------- 8.1/12.4 MB 20.8 MB/s eta 0:00:01
#    -------------------------- ------------- 8.1/12.4 MB 20.8 MB/s eta 0:00:01
#    ------------------------------ --------- 9.4/12.4 MB 18.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.1/12.4 MB 18.7 MB/s eta 0:00:01
#    ---------------------------------------  12.3/12.4 MB 20.5 MB/s eta 0:00:01
#    ---------------------------------------- 12.4/12.4 MB 19.9 MB/s eta 0:00:00
# Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading docutils-0.16-py2.py3-none-any.whl (548 kB)
#    ---------------------------------------- 0.0/548.2 kB ? eta -:--:--
#    --------------------------------------- 548.2/548.2 kB 35.9 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached PyYAML-6.0.1-cp311-cp311-win_amd64.whl (144 kB)
# Downloading rsa-4.7.2-py3-none-any.whl (34 kB)
# Downloading s3transfer-0.10.2-py3-none-any.whl (82 kB)
#    ---------------------------------------- 0.0/82.7 kB ? eta -:--:--
#    ---------------------------------------- 82.7/82.7 kB ? eta 0:00:00
# Using cached urllib3-2.2.2-py3-none-any.whl (121 kB)
# Downloading pyasn1-0.6.0-py2.py3-none-any.whl (85 kB)
#    ---------------------------------------- 0.0/85.3 kB ? eta -:--:--
#    ---------------------------------------- 85.3/85.3 kB 4.7 MB/s eta 0:00:00
# Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Installing collected packages: urllib3, six, PyYAML, pyasn1, jmespath, docutils, colorama, rsa, python-dateutil, botocore, s3transfer, boto3, awscli
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.2.2
#     Uninstalling urllib3-2.2.2:
#       Successfully uninstalled urllib3-2.2.2
#   Attempting uninstall: six
#     Found existing installation: six 1.16.0
#     Uninstalling six-1.16.0:
#       Successfully uninstalled six-1.16.0
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 6.0.1
#     Uninstalling PyYAML-6.0.1:
#       Successfully uninstalled PyYAML-6.0.1
#   Attempting uninstall: colorama
#     Found existing installation: colorama 0.4.6
#     Uninstalling colorama-0.4.6:
#       Successfully uninstalled colorama-0.4.6
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.9.0
#     Uninstalling python-dateutil-2.9.0:
#       Successfully uninstalled python-dateutil-2.9.0
# Successfully installed PyYAML-6.0.1 awscli-1.33.20 boto3-1.34.138 botocore-1.34.138 colorama-0.4.6 docutils-0.16 jmespath-1.0.1 pyasn1-0.6.0 python-dateutil-2.9.0.post0 rsa-4.7.2 s3transfer-0.10.2 six-1.16.0 urllib3-2.2.2
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: langchain in c:\users\user\anaconda3\envs\genia\lib\site-packages (0.2.5)
# Collecting pydantic==1.10.14
#   Downloading pydantic-1.10.14-cp311-cp311-win_amd64.whl.metadata (151 kB)
#      ---------------------------------------- 0.0/151.6 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/151.6 kB ? eta -:--:--
#      ------- ----------------------------- 30.7/151.6 kB 330.3 kB/s eta 0:00:01
#      ------------ ------------------------ 51.2/151.6 kB 375.8 kB/s eta 0:00:01
#      ----------------- ------------------- 71.7/151.6 kB 393.8 kB/s eta 0:00:01
#      ---------------------------------- - 143.4/151.6 kB 655.8 kB/s eta 0:00:01
#      ------------------------------------ 151.6/151.6 kB 648.3 kB/s eta 0:00:00
# Collecting transformers<5,>=4.24
#   Downloading transformers-4.42.3-py3-none-any.whl.metadata (43 kB)
#      ---------------------------------------- 0.0/43.6 kB ? eta -:--:--
#      ---------------------------------------- 43.6/43.6 kB ? eta 0:00:00
# Collecting faiss-cpu<2,>=1.7
#   Downloading faiss_cpu-1.8.0.post1-cp311-cp311-win_amd64.whl.metadata (3.8 kB)
# Collecting pypdf<4,>=3.8
#   Downloading pypdf-3.17.4-py3-none-any.whl.metadata (7.5 kB)
# Collecting datasets
#   Downloading datasets-2.20.0-py3-none-any.whl.metadata (19 kB)
# Collecting numexpr
#   Downloading numexpr-2.10.1-cp311-cp311-win_amd64.whl.metadata (1.3 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from pydantic==1.10.14) (4.12.2)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from langchain) (2.0.29)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from langchain) (3.9.5)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.7 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from langchain) (0.2.11)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from langchain) (0.2.1)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from langchain) (0.1.81)
# Requirement already satisfied: numpy<2,>=1 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from langchain) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from langchain) (8.4.1)
# Collecting filelock (from transformers<5,>=4.24)
#   Downloading filelock-3.15.4-py3-none-any.whl.metadata (2.9 kB)
# Collecting huggingface-hub<1.0,>=0.23.2 (from transformers<5,>=4.24)
#   Downloading huggingface_hub-0.23.4-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from transformers<5,>=4.24) (24.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from transformers<5,>=4.24) (2024.5.15)
# Collecting safetensors>=0.4.1 (from transformers<5,>=4.24)
#   Downloading safetensors-0.4.3-cp311-none-win_amd64.whl.metadata (3.9 kB)
# Collecting tokenizers<0.20,>=0.19 (from transformers<5,>=4.24)
#   Downloading tokenizers-0.19.1-cp311-none-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: tqdm>=4.27 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from transformers<5,>=4.24) (4.66.4)
# Collecting pyarrow>=15.0.0 (from datasets)
#   Downloading pyarrow-16.1.0-cp311-cp311-win_amd64.whl.metadata (3.1 kB)
# Collecting pyarrow-hotfix (from datasets)
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl.metadata (3.6 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in c:\users\user\anaconda3\envs\genia\lib\site-packages (from datasets) (2.2.2)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp311-cp311-win_amd64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.5.0,>=2023.1.0 (from fsspec[http]<=2024.5.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.5.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from langchain-core<0.3.0,>=0.2.7->langchain) (1.33)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from requests<3,>=2->langchain) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from requests<3,>=2->langchain) (2024.6.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\envs\genia\lib\site-packages (from tqdm>=4.27->transformers<5,>=4.24) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.7->langchain) (3.0.0)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Downloading pydantic-1.10.14-cp311-cp311-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.2/2.1 MB 3.7 MB/s eta 0:00:01
#    --- ------------------------------------ 0.2/2.1 MB 2.1 MB/s eta 0:00:01
#    -------- ------------------------------- 0.4/2.1 MB 3.4 MB/s eta 0:00:01
#    --------- ------------------------------ 0.5/2.1 MB 2.6 MB/s eta 0:00:01
#    ------------------ --------------------- 1.0/2.1 MB 4.4 MB/s eta 0:00:01
#    -------------------- ------------------- 1.1/2.1 MB 3.9 MB/s eta 0:00:01
#    -------------------------------------- - 2.0/2.1 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 5.6 MB/s eta 0:00:00
# Downloading transformers-4.42.3-py3-none-any.whl (9.3 MB)
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    --------- ------------------------------ 2.2/9.3 MB 46.0 MB/s eta 0:00:01
#    --------- ------------------------------ 2.3/9.3 MB 23.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.6/9.3 MB 39.4 MB/s eta 0:00:01
#    --------------------------- ------------ 6.5/9.3 MB 34.5 MB/s eta 0:00:01
#    -------------------------------------- - 9.0/9.3 MB 41.2 MB/s eta 0:00:01
#    -------------------------------------- - 9.0/9.3 MB 41.2 MB/s eta 0:00:01
#    ---------------------------------------  9.2/9.3 MB 28.0 MB/s eta 0:00:01
#    ---------------------------------------  9.3/9.3 MB 28.3 MB/s eta 0:00:01
#    ---------------------------------------- 9.3/9.3 MB 22.9 MB/s eta 0:00:00
# Downloading faiss_cpu-1.8.0.post1-cp311-cp311-win_amd64.whl (14.6 MB)
#    ---------------------------------------- 0.0/14.6 MB ? eta -:--:--
#    ------- -------------------------------- 2.8/14.6 MB 175.4 MB/s eta 0:00:01
#    ------- -------------------------------- 2.8/14.6 MB 175.4 MB/s eta 0:00:01
#    ------------ --------------------------- 4.4/14.6 MB 35.2 MB/s eta 0:00:01
#    ------------ --------------------------- 4.6/14.6 MB 32.8 MB/s eta 0:00:01
#    ----------------- ---------------------- 6.3/14.6 MB 28.8 MB/s eta 0:00:01
#    ----------------- ---------------------- 6.3/14.6 MB 28.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 8.3/14.6 MB 26.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 8.3/14.6 MB 26.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 10.5/14.6 MB 25.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 10.5/14.6 MB 25.2 MB/s eta 0:00:01
#    -------------------------------- ------- 12.0/14.6 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  14.6/14.6 MB 24.2 MB/s eta 0:00:01
#    ---------------------------------------- 14.6/14.6 MB 23.3 MB/s eta 0:00:00
# Downloading pypdf-3.17.4-py3-none-any.whl (278 kB)
#    ---------------------------------------- 0.0/278.2 kB ? eta -:--:--
#    ---------------------------------------- 278.2/278.2 kB ? eta 0:00:00
# Downloading datasets-2.20.0-py3-none-any.whl (547 kB)
#    ---------------------------------------- 0.0/547.8 kB ? eta -:--:--
#    --------------------------------------- 547.8/547.8 kB 35.8 MB/s eta 0:00:00
# Downloading numexpr-2.10.1-cp311-cp311-win_amd64.whl (141 kB)
#    ---------------------------------------- 0.0/141.2 kB ? eta -:--:--
#    ---------------------------------------- 141.2/141.2 kB 8.2 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ---------------------------------------- 0.0/116.3 kB ? eta -:--:--
#    ---------------------------------------- 116.3/116.3 kB ? eta 0:00:00
# Downloading fsspec-2024.5.0-py3-none-any.whl (316 kB)
#    ---------------------------------------- 0.0/316.1 kB ? eta -:--:--
#    ---------------------------------------- 316.1/316.1 kB ? eta 0:00:00
# Downloading huggingface_hub-0.23.4-py3-none-any.whl (402 kB)
#    ---------------------------------------- 0.0/402.6 kB ? eta -:--:--
#    --------------------------------------- 402.6/402.6 kB 26.2 MB/s eta 0:00:00
# Downloading pyarrow-16.1.0-cp311-cp311-win_amd64.whl (25.9 MB)
#    ---------------------------------------- 0.0/25.9 MB ? eta -:--:--
#    --- ------------------------------------ 2.3/25.9 MB 75.0 MB/s eta 0:00:01
#    ------- -------------------------------- 4.7/25.9 MB 59.6 MB/s eta 0:00:01
#    ---------- ----------------------------- 7.0/25.9 MB 56.2 MB/s eta 0:00:01
#    -------------- ------------------------- 9.3/25.9 MB 59.7 MB/s eta 0:00:01
#    ------------------ --------------------- 11.7/25.9 MB 50.4 MB/s eta 0:00:01
#    --------------------- ------------------ 14.0/25.9 MB 54.4 MB/s eta 0:00:01
#    ------------------------- -------------- 16.5/25.9 MB 50.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 18.8/25.9 MB 50.4 MB/s eta 0:00:01
#    --------------------------------- ------ 21.4/25.9 MB 50.4 MB/s eta 0:00:01
#    ------------------------------------ --- 23.6/25.9 MB 50.4 MB/s eta 0:00:01
#    ---------------------------------------  25.9/25.9 MB 54.7 MB/s eta 0:00:01
#    ---------------------------------------- 25.9/25.9 MB 46.7 MB/s eta 0:00:00
# Downloading safetensors-0.4.3-cp311-none-win_amd64.whl (287 kB)
#    ---------------------------------------- 0.0/287.3 kB ? eta -:--:--
#    ---------------------------------------- 287.3/287.3 kB ? eta 0:00:00
# Downloading tokenizers-0.19.1-cp311-none-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 47.0 MB/s eta 0:00:00
# Downloading filelock-3.15.4-py3-none-any.whl (16 kB)
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ---------------------------------------- 0.0/143.5 kB ? eta -:--:--
#    ---------------------------------------- 143.5/143.5 kB 8.3 MB/s eta 0:00:00
# Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Downloading xxhash-3.4.1-cp311-cp311-win_amd64.whl (29 kB)
# Installing collected packages: xxhash, safetensors, pypdf, pydantic, pyarrow-hotfix, pyarrow, numexpr, fsspec, filelock, faiss-cpu, dill, multiprocess, huggingface-hub, tokenizers, transformers, datasets
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.7.1
#     Uninstalling pydantic-2.7.1:
#       Successfully uninstalled pydantic-2.7.1
# Successfully installed datasets-2.20.0 dill-0.3.8 faiss-cpu-1.8.0.post1 filelock-3.15.4 fsspec-2024.5.0 huggingface-hub-0.23.4 multiprocess-0.70.16 numexpr-2.10.1 pyarrow-16.1.0 pyarrow-hotfix-0.6 pydantic-1.10.14 pypdf-3.17.4 safetensors-0.4.3 tokenizers-0.19.1 transformers-4.42.3 xxhash-3.4.1
# Note: you may need to restart the kernel to use updated packages.
# Collecting google-search-results
#   Downloading google_search_results-2.4.2.tar.gz (18 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: requests in c:\users\user\anaconda3\envs\genia\lib\site-packages (from google-search-results) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from requests->google-search-results) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from requests->google-search-results) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from requests->google-search-results) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from requests->google-search-results) (2024.6.2)
# Building wheels for collected packages: google-search-results
#   Building wheel for google-search-results (setup.py): started
#   Building wheel for google-search-results (setup.py): finished with status 'done'
#   Created wheel for google-search-results: filename=google_search_results-2.4.2-py3-none-any.whl size=32083 sha256=0d0809aba1e5a6b19edb91fb5c239e015999575417e765382ef789b527c3a91b
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\6e\42\3e\aeb691b02cb7175ec70e2da04b5658d4739d2b41e5f73cd06f
# Successfully built google-search-results
# Installing collected packages: google-search-results
# Successfully installed google-search-results-2.4.2
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: SQLAlchemy in c:\users\user\anaconda3\envs\genia\lib\site-packages (2.0.29)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from SQLAlchemy) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from SQLAlchemy) (3.0.3)
# Collecting flask-sqlalchemy
#   Downloading flask_sqlalchemy-3.1.1-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: flask>=2.2.5 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from flask-sqlalchemy) (3.0.3)
# Requirement already satisfied: sqlalchemy>=2.0.16 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from flask-sqlalchemy) (2.0.29)
# Requirement already satisfied: Werkzeug>=3.0.0 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from flask>=2.2.5->flask-sqlalchemy) (3.0.3)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from flask>=2.2.5->flask-sqlalchemy) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from flask>=2.2.5->flask-sqlalchemy) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from flask>=2.2.5->flask-sqlalchemy) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from flask>=2.2.5->flask-sqlalchemy) (1.8.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from sqlalchemy>=2.0.16->flask-sqlalchemy) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from sqlalchemy>=2.0.16->flask-sqlalchemy) (3.0.3)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\envs\genia\lib\site-packages (from click>=8.1.3->flask>=2.2.5->flask-sqlalchemy) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from Jinja2>=3.1.2->flask>=2.2.5->flask-sqlalchemy) (2.1.5)
# Downloading flask_sqlalchemy-3.1.1-py3-none-any.whl (25 kB)
# Installing collected packages: flask-sqlalchemy
# Successfully installed flask-sqlalchemy-3.1.1
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: langchain_community in c:\users\user\anaconda3\envs\genia\lib\site-packages (0.2.5)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from langchain_community) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from langchain_community) (2.0.29)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from langchain_community) (3.9.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: langchain<0.3.0,>=0.2.5 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from langchain_community) (0.2.5)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.7 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from langchain_community) (0.2.11)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from langchain_community) (0.1.81)
# Requirement already satisfied: numpy<2,>=1 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from langchain_community) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from langchain_community) (2.32.3)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from langchain_community) (8.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.9.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from langchain<0.3.0,>=0.2.5->langchain_community) (0.2.1)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from langchain<0.3.0,>=0.2.5->langchain_community) (1.10.14)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from langchain-core<0.3.0,>=0.2.7->langchain_community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from langchain-core<0.3.0,>=0.2.7->langchain_community) (24.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain_community) (3.10.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from requests<3,>=2->langchain_community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from requests<3,>=2->langchain_community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from requests<3,>=2->langchain_community) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from requests<3,>=2->langchain_community) (2024.6.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.0.3)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.7->langchain_community) (3.0.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\user\anaconda3\envs\genia\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Restart the kernel after running the above cell
